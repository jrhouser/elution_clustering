# %%
####compare against randomized (control) complexes

df_random=pd.read_csv('../testdata/PA/GMM_cluster_0.9_metrics_filtone_randomized.csv')
df_bayes_random=pd.read_csv('../testdata/PA/GMM_cluster_bayes_0.9_metrics_filtone_randomized.csv')

df_random=df_random.set_index('Unnamed: 0').T
df_bayes_random=df_bayes_random.set_index('Unnamed: 0').T

df_gmm_combo=pd.concat([df,df_random],axis=1)
df_bayes_combo=pd.concat([df_bayes,df_bayes_random],axis=1)

ax = df_bayes_combo.plot(kind='bar',figsize=(15,5),fontsize=20)

patches, labels = ax.get_legend_handles_labels()
ax.legend(patches, labels, loc='best')

ax2 = df_gmm_combo.plot(kind='bar',figsize=(15,5),fontsize=20)

patches, labels = ax2.get_legend_handles_labels()
ax2.legend(patches, labels, loc='best')

#df_bayes.set_index('Unnamed: 0').T.plot(kind='bar')
plt.show()

# %%
# %matplotlib inline

import pylab as plt
import pandas as pd
import numpy as np
import cPickle


df=pd.read_csv('../testdata/PA/GMM_cluster_0.9_metrics_filtone.csv')
df_bayes=pd.read_csv('../testdata/PA/GMM_cluster_bayes_0.9_metrics_filtone.csv')

df=df.set_index('Unnamed: 0').T
df_bayes=df_bayes.set_index('Unnamed: 0').T

df_combo=pd.concat([df,df_bayes],axis=1)

ax = df_combo.plot(kind='bar',figsize=(15,5),fontsize=20)

patches, labels = ax.get_legend_handles_labels()
ax.legend(patches, labels, loc='best')

#df_bayes.set_index('Unnamed: 0').T.plot(kind='bar')
plt.show()
